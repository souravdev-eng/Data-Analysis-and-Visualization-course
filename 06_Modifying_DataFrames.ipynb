# %%
import pandas as pd
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")
netflix = pd.read_csv("data/netflix_titles.csv", sep="|", index_col=0)
btc = pd.read_csv("data/coin_Bitcoin.csv")
countries = pd.read_csv("data/world-happiness-report-2021.csv")

# %%
countries.set_index("Country name", inplace=True)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
countries.head()
# Out:
#              Regional indicator  Ladder score  ...  Explained by: Perceptions of corruption  Dystopia + residual
# Country name                                   ...
# Finland          Western Europe         7.842  ...                                    0.481                3.253
# Denmark          Western Europe         7.620  ...                                    0.485                2.868
# Switzerland      Western Europe         7.571  ...                                    0.413                2.839
# Iceland          Western Europe         7.554  ...                                    0.170                2.967
# Netherlands      Western Europe         7.464  ...                                    0.384                2.798
#
# [5 rows x 19 columns]

# %% [markdown]
# ## `drop()` columns

# %%
btc.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low        Open       Close  Volume     Marketcap
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000  134.444000  144.539993     0.0  1.603769e+09
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003  144.000000  139.000000     0.0  1.542813e+09
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001  139.000000  116.989998     0.0  1.298955e+09
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898  116.379997  105.209999     0.0  1.168517e+09
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998  106.250000   97.750000     0.0  1.085995e+09

# %% [markdown]
# **`axis=1` or `columns` means the `columns` we are deleting**

# %%
btc.drop(labels="Symbol", axis=1)
# Out:
#        SNo     Name                 Date          High           Low          Open         Close        Volume     Marketcap
# 0        1  Bitcoin  2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin  2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin  2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin  2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin  2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...                  ...           ...           ...           ...           ...           ...           ...
# ...

# %%
btc.drop(labels=["SNo", "Name", "Symbol"], axis=1)
# Out:
#                      Date          High           Low          Open         Close        Volume     Marketcap
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993  0.000000e+00  1.603769e+09
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000  0.000000e+00  1.542813e+09
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998  0.000000e+00  1.298955e+09
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999  0.000000e+00  1.168517e+09
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000  0.000000e+00  1.085995e+09
# ...                   ...           ...           ...           ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# ...

# %%
# btc.drop(labels=["SNo", "Name", "Symbol"], axis=1)
btc.drop(columns=["SNo", "Name", "Symbol"])
# Out:
#                      Date          High           Low          Open         Close        Volume     Marketcap
# 0     2013-04-29 23:59:59    147.488007    134.000000    134.444000    144.539993  0.000000e+00  1.603769e+09
# 1     2013-04-30 23:59:59    146.929993    134.050003    144.000000    139.000000  0.000000e+00  1.542813e+09
# 2     2013-05-01 23:59:59    139.889999    107.720001    139.000000    116.989998  0.000000e+00  1.298955e+09
# 3     2013-05-02 23:59:59    125.599998     92.281898    116.379997    105.209999  0.000000e+00  1.168517e+09
# 4     2013-05-03 23:59:59    108.127998     79.099998    106.250000     97.750000  0.000000e+00  1.085995e+09
# ...                   ...           ...           ...           ...           ...           ...           ...
# 2986  2021-07-02 23:59:59  33939.588699  32770.680780  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# ...

# %% [markdown]
# ## `drop()` rows

# %%
countries.drop(labels="Denmark", axis=0)
# Out:
#               Regional indicator  Ladder score  ...  Explained by: Perceptions of corruption  Dystopia + residual
# Country name                                    ...
# Finland           Western Europe         7.842  ...                                    0.481                3.253
# Switzerland       Western Europe         7.571  ...                                    0.413                2.839
# Iceland           Western Europe         7.554  ...                                    0.170                2.967
# Netherlands       Western Europe         7.464  ...                                    0.384                2.798
# Norway            Western Europe         7.392  ...                                    0.427                2.580
# ...                          ...           ...  ...                                      ...                  ...
# Lesotho       Sub-Saharan Africa         3.512  ...                                    0.015                1.800
# ...

# %%
btc.drop(labels=2990, axis=0)
# Out:
#        SNo     Name Symbol                 Date  ...          Open         Close        Volume     Marketcap
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59  ...    134.444000    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59  ...    144.000000    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59  ...    139.000000    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59  ...    116.379997    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59  ...    106.250000     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...    ...                  ...  ...           ...           ...           ...           ...
# 2985  2986  Bitcoin    BTC  2021-07-01 23:59:59  ...  35035.982712  33572.117653  3.783896e+10  6.293393e+11
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  ...  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# ...

# %% [markdown]
# ### `drop()` rows by position

# %%
countries.drop(countries.index[0:3]) # rows direction is "--"
# Out:
#               Regional indicator  Ladder score  ...  Explained by: Perceptions of corruption  Dystopia + residual
# Country name                                    ...
# Iceland           Western Europe         7.554  ...                                    0.170                2.967
# Netherlands       Western Europe         7.464  ...                                    0.384                2.798
# Norway            Western Europe         7.392  ...                                    0.427                2.580
# Sweden            Western Europe         7.363  ...                                    0.448                2.683
# Luxembourg        Western Europe         7.324  ...                                    0.353                2.653
# ...                          ...           ...  ...                                      ...                  ...
# Lesotho       Sub-Saharan Africa         3.512  ...                                    0.015                1.800
# ...

# %% [markdown]
# ## Add new `columns` in DF

# %%
titanic["species"] = "human"
titanic
# Out:
#       pclass  survived                                             name  ... body                        home.dest  species
# 0          1         1                    Allen, Miss. Elisabeth Walton  ...    ?                     St Louis, MO    human
# 1          1         1                   Allison, Master. Hudson Trevor  ...    ?  Montreal, PQ / Chesterville, ON    human
# 2          1         0                     Allison, Miss. Helen Loraine  ...    ?  Montreal, PQ / Chesterville, ON    human
# 3          1         0             Allison, Mr. Hudson Joshua Creighton  ...  135  Montreal, PQ / Chesterville, ON    human
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  ...    ?  Montreal, PQ / Chesterville, ON    human
# ...      ...       ...                                              ...  ...  ...                              ...      ...
# ...

# %%
houses.insert(0,"county", "King County")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 houses.insert(0,"county", "King County")
#
# File C:\sourav_projects\data-analysis-and-visualization\env\Lib\site-packages\pandas\core\frame.py:4817, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4811     raise ValueError(
#    4812         "Cannot specify 'allow_duplicates=True' when "
#    4813         "'self.flags.allows_duplicate_labels' is False."
#    4814     )
#    4815 if not allow_duplicates and column in self.columns:
#    4816     # Should this be a different kind of error??
# -> 4817     raise ValueError(f"cannot insert {column}, already exists")
#    4818 if not isinstance(loc, int):
#    4819     raise TypeError("loc must be int")
#
# ValueError: cannot insert county, already exists

# %%
houses
# Out:
#             county          id             date     price  bedrooms  ...  zipcode      lat     long  sqft_living15  sqft_lot15
# 0      King County  7129300520  20141013T000000  221900.0         3  ...    98178  47.5112 -122.257           1340        5650
# 1      King County  6414100192  20141209T000000  538000.0         3  ...    98125  47.7210 -122.319           1690        7639
# 2      King County  5631500400  20150225T000000  180000.0         2  ...    98028  47.7379 -122.233           2720        8062
# 3      King County  2487200875  20141209T000000  604000.0         4  ...    98136  47.5208 -122.393           1360        5000
# 4      King County  1954400510  20150218T000000  510000.0         3  ...    98074  47.6168 -122.045           1800        7503
# ...            ...         ...              ...       ...       ...  ...      ...      ...      ...            ...         ...
# ...
