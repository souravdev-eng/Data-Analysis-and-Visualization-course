# %%
import pandas as pd
btc = pd.read_csv("data/coin_Bitcoin.csv")
btc
# Out:
#        SNo     Name Symbol                 Date  ...          Open         Close        Volume     Marketcap
# 0        1  Bitcoin    BTC  2013-04-29 23:59:59  ...    134.444000    144.539993  0.000000e+00  1.603769e+09
# 1        2  Bitcoin    BTC  2013-04-30 23:59:59  ...    144.000000    139.000000  0.000000e+00  1.542813e+09
# 2        3  Bitcoin    BTC  2013-05-01 23:59:59  ...    139.000000    116.989998  0.000000e+00  1.298955e+09
# 3        4  Bitcoin    BTC  2013-05-02 23:59:59  ...    116.379997    105.209999  0.000000e+00  1.168517e+09
# 4        5  Bitcoin    BTC  2013-05-03 23:59:59  ...    106.250000     97.750000  0.000000e+00  1.085995e+09
# ...    ...      ...    ...                  ...  ...           ...           ...           ...           ...
# 2986  2987  Bitcoin    BTC  2021-07-02 23:59:59  ...  33549.600177  33897.048590  3.872897e+10  6.354508e+11
# 2987  2988  Bitcoin    BTC  2021-07-03 23:59:59  ...  33854.421362  34668.548402  2.438396e+10  6.499397e+11
# ...

# %%
btc.set_index("Date", inplace=True)

# %%
btc.High.plot();

# %%
# Set index column while import the data

countries = pd.read_csv("data/world-happiness-report-2021.csv", index_col=0)
countries.head()
# Out:
#              Regional indicator  Ladder score  ...  Explained by: Perceptions of corruption  Dystopia + residual
# Country name                                   ...
# Finland          Western Europe         7.842  ...                                    0.481                3.253
# Denmark          Western Europe         7.620  ...                                    0.485                2.868
# Switzerland      Western Europe         7.571  ...                                    0.413                2.839
# Iceland          Western Europe         7.554  ...                                    0.170                2.967
# Netherlands      Western Europe         7.464  ...                                    0.384                2.798
#
# [5 rows x 19 columns]

# %%
countries["Ladder score"]
# Out:
# Country name
# Finland        7.842
# Denmark        7.620
# Switzerland    7.571
# Iceland        7.554
# Netherlands    7.464
#                ...
# Lesotho        3.512
# Botswana       3.467
# Rwanda         3.415
# Zimbabwe       3.145
# Afghanistan    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
# Assending sorting (means low value first and lagre scend)
df.sort_values("Healthy life expectancy")
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Chad                       Sub-Saharan Africa  ...                3.209
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Swaziland                  Sub-Saharan Africa  ...                2.155
# ...                                       ...  ...                  ...
# Switzerland                    Western Europe  ...                2.839
# Spain                          Western Europe  ...                2.513
# Japan                               East Asia  ...                2.048
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Singapore                      Southeast Asia  ...                1.379
#
# [149 rows x 19 columns]

# %%
countries.sort_values("Healthy life expectancy", ascending=False)
# Out:
#                            Regional indicator  ...  Dystopia + residual
# Country name                                   ...
# Singapore                      Southeast Asia  ...                1.379
# Hong Kong S.A.R. of China           East Asia  ...                1.236
# Japan                               East Asia  ...                2.048
# Spain                          Western Europe  ...                2.513
# Switzerland                    Western Europe  ...                2.839
# ...                                       ...  ...                  ...
# Swaziland                  Sub-Saharan Africa  ...                2.155
# Ivory Coast                Sub-Saharan Africa  ...                3.469
# Nigeria                    Sub-Saharan Africa  ...                2.736
# Lesotho                    Sub-Saharan Africa  ...                1.800
# Chad                       Sub-Saharan Africa  ...                3.209
#
# [149 rows x 19 columns]

# %%
countries
# Out:
#               Regional indicator  ...  Dystopia + residual
# Country name                      ...
# Finland           Western Europe  ...                3.253
# Denmark           Western Europe  ...                2.868
# Switzerland       Western Europe  ...                2.839
# Iceland           Western Europe  ...                2.967
# Netherlands       Western Europe  ...                2.798
# ...                          ...  ...                  ...
# Lesotho       Sub-Saharan Africa  ...                1.800
# Botswana      Sub-Saharan Africa  ...                0.648
# Rwanda        Sub-Saharan Africa  ...                1.095
# Zimbabwe      Sub-Saharan Africa  ...                1.205
# Afghanistan           South Asia  ...                1.895
#
# [149 rows x 19 columns]

# %% [markdown]
# ### Sorting multipale columns

# %%
houses = pd.read_csv("data/kc_house_data.csv")
titanic = pd.read_csv("data/titanic.csv")

# %%
houses.head()
# Out:
#            id             date     price  bedrooms  ...      lat     long  sqft_living15  sqft_lot15
# 0  7129300520  20141013T000000  221900.0         3  ...  47.5112 -122.257           1340        5650
# 1  6414100192  20141209T000000  538000.0         3  ...  47.7210 -122.319           1690        7639
# 2  5631500400  20150225T000000  180000.0         2  ...  47.7379 -122.233           2720        8062
# 3  2487200875  20141209T000000  604000.0         4  ...  47.5208 -122.393           1360        5000
# 4  1954400510  20150218T000000  510000.0         3  ...  47.6168 -122.045           1800        7503
#
# [5 rows x 21 columns]

# %%
houses.sort_values("price", ascending=False)
# Out:
#                id             date      price  bedrooms  ...      lat     long  sqft_living15  sqft_lot15
# 7252   6762700020  20141013T000000  7700000.0         6  ...  47.6298 -122.323           3940        8800
# 3914   9808700762  20140611T000000  7062500.0         5  ...  47.6500 -122.214           3930       25449
# 9254   9208900037  20140919T000000  6885000.0         6  ...  47.6305 -122.240           4540       42730
# 4411   2470100110  20140804T000000  5570000.0         5  ...  47.6289 -122.233           3560       24345
# 1448   8907500070  20150413T000000  5350000.0         5  ...  47.6232 -122.220           4600       21750
# ...           ...              ...        ...       ...  ...      ...      ...            ...         ...
# 8274   3883800011  20141105T000000    82000.0         3  ...  47.4987 -122.341           1140       11250
# 16198  3028200080  20150324T000000    81000.0         2  ...  47.4808 -122.315            860        9000
# ...

# %%
houses.sort_values("bedrooms", ascending=False)
# Out:
#                id             date      price  bedrooms  ...      lat     long  sqft_living15  sqft_lot15
# 15870  2402100895  20140625T000000   640000.0        33  ...  47.6878 -122.331           1330        4700
# 8757   1773100755  20140821T000000   520000.0        11  ...  47.5560 -122.363           1420        4960
# 15161  5566100170  20141029T000000   650000.0        10  ...  47.5705 -122.175           2040       11914
# 13314   627300145  20140814T000000  1148000.0        10  ...  47.5861 -122.113           2730       10400
# 19254  8812401450  20141229T000000   660000.0        10  ...  47.6635 -122.320           1810        3745
# ...           ...              ...        ...       ...  ...      ...      ...            ...         ...
# 19452  3980300371  20140926T000000   142000.0         0  ...  47.5308 -121.888           1620       22850
# 8484   2310060040  20140925T000000   240000.0         0  ...  47.3493 -122.053           1810        5685
# ...

# %%
houses.sort_values(["bedrooms", "bathrooms"], ascending=False)
# Out:
#                id             date      price  bedrooms  ...      lat     long  sqft_living15  sqft_lot15
# 15870  2402100895  20140625T000000   640000.0        33  ...  47.6878 -122.331           1330        4700
# 8757   1773100755  20140821T000000   520000.0        11  ...  47.5560 -122.363           1420        4960
# 13314   627300145  20140814T000000  1148000.0        10  ...  47.5861 -122.113           2730       10400
# 19254  8812401450  20141229T000000   660000.0        10  ...  47.6635 -122.320           1810        3745
# 15161  5566100170  20141029T000000   650000.0        10  ...  47.5705 -122.175           2040       11914
# ...           ...              ...        ...       ...  ...      ...      ...            ...         ...
# 6994   2954400190  20140624T000000  1295650.0         0  ...  47.6642 -122.069           4740       35061
# 9773   3374500520  20150429T000000   355000.0         0  ...  47.4095 -122.168           2520        8050
# ...

# %% [markdown]
# ### Sorting Text Columns

# %%
titanic.head()
# Out:
#    pclass  survived  ... body                        home.dest
# 0       1         1  ...    ?                     St Louis, MO
# 1       1         1  ...    ?  Montreal, PQ / Chesterville, ON
# 2       1         0  ...    ?  Montreal, PQ / Chesterville, ON
# 3       1         0  ...  135  Montreal, PQ / Chesterville, ON
# 4       1         0  ...    ?  Montreal, PQ / Chesterville, ON
#
# [5 rows x 14 columns]

# %%
# Not correct sorting!
titanic.sort_values("name")
# Out:
#       pclass  survived                                           name  ... boat body                  home.dest
# 600        3         0                            Abbing, Mr. Anthony  ...    ?    ?                          ?
# 601        3         0                  Abbott, Master. Eugene Joseph  ...    ?    ?        East Providence, RI
# 602        3         0                    Abbott, Mr. Rossmore Edward  ...    ?  190        East Providence, RI
# 603        3         1               Abbott, Mrs. Stanton (Rosa Hunt)  ...    A    ?        East Providence, RI
# 604        3         1                    Abelseth, Miss. Karen Marie  ...   16    ?     Norway Los Angeles, CA
# ...      ...       ...                                            ...  ...  ...  ...                        ...
# 392        2         1  del Carlo, Mrs. Sebastiano (Argenia Genovesi)  ...   12    ?  Lucca, Italy / California
# ...

# %%
titanic.sort_values("name", key=lambda col: col.str.lower())
# Out:
#       pclass  survived                              name     sex  ... embarked  boat  body               home.dest
# 600        3         0               Abbing, Mr. Anthony    male  ...        S     ?     ?                       ?
# 601        3         0     Abbott, Master. Eugene Joseph    male  ...        S     ?     ?     East Providence, RI
# 602        3         0       Abbott, Mr. Rossmore Edward    male  ...        S     ?   190     East Providence, RI
# 603        3         1  Abbott, Mrs. Stanton (Rosa Hunt)  female  ...        S     A     ?     East Providence, RI
# 604        3         1       Abelseth, Miss. Karen Marie  female  ...        S    16     ?  Norway Los Angeles, CA
# ...      ...       ...                               ...     ...  ...      ...   ...   ...                     ...
# 1304       3         0              Zabour, Miss. Hileni  female  ...        C     ?   328                       ?
# ...
