# %% [markdown]
# # Adding & Removing Columns Exercise

# %%
import pandas as pd
tweet = pd.read_csv("data/JoeBidenTweets.csv")
tweet.head()
# Out:
#                    id         timestamp                                                url  ... retweets  quotes  likes
# 0           361388562  2007-10-24 22:45      https://twitter.com/JoeBiden/status/361388562  ...        5      17     11
# 1           543984392  2007-12-29 15:35      https://twitter.com/JoeBiden/status/543984392  ...       16       6     22
# 2  189287227321356289  2012-04-09 09:42  https://twitter.com/JoeBiden/status/1892872273...  ...       82       1     20
# 3  189287350034104320  2012-04-09 09:43  https://twitter.com/JoeBiden/status/1892873500...  ...       76      37     51
# 4  189339650610036736  2012-04-09 13:11  https://twitter.com/JoeBiden/status/1893396506...  ...       54       0      5
#
# [5 rows x 8 columns]

# %%
#Import the JoeBidenTweets.csv dataset.  Use the tweet "id" as the index
tweet.set_index("id", inplace=True)

# %%
#Drop the "url" column (NOT inplace)
tweet.drop("url", axis=1)
# Out:
#                             timestamp                                              tweet  replies  retweets  quotes  likes
# id
# 361388562            2007-10-24 22:45  Tune in 11:30 ET tomorrow for a live webcast o...       19         5      17     11
# 543984392            2007-12-29 15:35  Iowans, there's a good chance there's a Biden ...       13        16       6     22
# 189287227321356289   2012-04-09 09:42  We're excited to announce that @JoeBiden is be...       21        82       1     20
# 189287350034104320   2012-04-09 09:43  Campaign staff will run this account to keep y...      144        76      37     51
# 189339650610036736   2012-04-09 13:11  News for you this morning: VP Biden will speak...       10        54       0      5
# ...                               ...                                                ...      ...       ...     ...    ...
# 1322865972819251200  2020-11-01 11:40  As president, I’ll build an economy that rewar...     3085      3654     480  36995
# 1322871257902145536  2020-11-01 12:01  Let’s put dogs back in the White House. https:...     2211      4211    1246  34240
# 1322876039144636417  2020-11-01 12:20  We have in our hands the ultimate power: the p...      918      1143     122   6954
# 1322881072363917312  2020-11-01 12:40  We need to:\n\nBuild bridges, not walls.\nOpen...     1281      2255     344  16696
# 1322886357535150081  2020-11-01 13:01  Jodie –– you have my word: I will always stand...      168       270      37   1648
#
# [6064 rows x 6 columns]

# %%
#Drop the row with the id of 361388562(NOT inplace)
tweet.drop(labels=361388562, axis=0)
# Out:
#                             timestamp                                                url  ... quotes  likes
# id                                                                                        ...
# 543984392            2007-12-29 15:35      https://twitter.com/JoeBiden/status/543984392  ...      6     22
# 189287227321356289   2012-04-09 09:42  https://twitter.com/JoeBiden/status/1892872273...  ...      1     20
# 189287350034104320   2012-04-09 09:43  https://twitter.com/JoeBiden/status/1892873500...  ...     37     51
# 189339650610036736   2012-04-09 13:11  https://twitter.com/JoeBiden/status/1893396506...  ...      0      5
# 189343279140184065   2012-04-09 13:25  https://twitter.com/JoeBiden/status/1893432791...  ...      0      6
# ...                               ...                                                ...  ...    ...    ...
# 1322865972819251200  2020-11-01 11:40  https://twitter.com/JoeBiden/status/1322865972...  ...    480  36995
# 1322871257902145536  2020-11-01 12:01  https://twitter.com/JoeBiden/status/1322871257...  ...   1246  34240
# 1322876039144636417  2020-11-01 12:20  https://twitter.com/JoeBiden/status/1322876039...  ...    122   6954
# 1322881072363917312  2020-11-01 12:40  https://twitter.com/JoeBiden/status/1322881072...  ...    344  16696
# 1322886357535150081  2020-11-01 13:01  https://twitter.com/JoeBiden/status/1322886357...  ...     37   1648
#
# [6063 rows x 7 columns]

# %%
#Add a new column called "user".  Set it to "Joe Biden" for all rows
tweet["user"] = "Joe Biden"

# %%
tweet
# Out:
#                             timestamp                                                url  ...  likes       user
# id                                                                                        ...
# 361388562            2007-10-24 22:45      https://twitter.com/JoeBiden/status/361388562  ...     11  Joe Biden
# 543984392            2007-12-29 15:35      https://twitter.com/JoeBiden/status/543984392  ...     22  Joe Biden
# 189287227321356289   2012-04-09 09:42  https://twitter.com/JoeBiden/status/1892872273...  ...     20  Joe Biden
# 189287350034104320   2012-04-09 09:43  https://twitter.com/JoeBiden/status/1892873500...  ...     51  Joe Biden
# 189339650610036736   2012-04-09 13:11  https://twitter.com/JoeBiden/status/1893396506...  ...      5  Joe Biden
# ...                               ...                                                ...  ...    ...        ...
# 1322865972819251200  2020-11-01 11:40  https://twitter.com/JoeBiden/status/1322865972...  ...  36995  Joe Biden
# 1322871257902145536  2020-11-01 12:01  https://twitter.com/JoeBiden/status/1322871257...  ...  34240  Joe Biden
# 1322876039144636417  2020-11-01 12:20  https://twitter.com/JoeBiden/status/1322876039...  ...   6954  Joe Biden
# 1322881072363917312  2020-11-01 12:40  https://twitter.com/JoeBiden/status/1322881072...  ...  16696  Joe Biden
# 1322886357535150081  2020-11-01 13:01  https://twitter.com/JoeBiden/status/1322886357...  ...   1648  Joe Biden
#
# [6064 rows x 8 columns]

# %%
#Create a new column called "ratio".  It should contain the result of dividing each tweet's replies by its retweets
tweet["ratio"] = tweet["replies"] / tweet["retweets"]
tweet
# Out:
#                             timestamp                                                url  ...       user     ratio
# id                                                                                        ...
# 361388562            2007-10-24 22:45      https://twitter.com/JoeBiden/status/361388562  ...  Joe Biden  3.800000
# 543984392            2007-12-29 15:35      https://twitter.com/JoeBiden/status/543984392  ...  Joe Biden  0.812500
# 189287227321356289   2012-04-09 09:42  https://twitter.com/JoeBiden/status/1892872273...  ...  Joe Biden  0.256098
# 189287350034104320   2012-04-09 09:43  https://twitter.com/JoeBiden/status/1892873500...  ...  Joe Biden  1.894737
# 189339650610036736   2012-04-09 13:11  https://twitter.com/JoeBiden/status/1893396506...  ...  Joe Biden  0.185185
# ...                               ...                                                ...  ...        ...       ...
# 1322865972819251200  2020-11-01 11:40  https://twitter.com/JoeBiden/status/1322865972...  ...  Joe Biden  0.844280
# 1322871257902145536  2020-11-01 12:01  https://twitter.com/JoeBiden/status/1322871257...  ...  Joe Biden  0.525053
# 1322876039144636417  2020-11-01 12:20  https://twitter.com/JoeBiden/status/1322876039...  ...  Joe Biden  0.803150
# 1322881072363917312  2020-11-01 12:40  https://twitter.com/JoeBiden/status/1322881072...  ...  Joe Biden  0.568071
# 1322886357535150081  2020-11-01 13:01  https://twitter.com/JoeBiden/status/1322886357...  ...  Joe Biden  0.622222
#
# [6064 rows x 9 columns]

# %%
#Find the top 10 highest ratio tweets
tweet["ratio"].sort_values(ascending=False).head(10)
# Out:
# id
# 232971730119950338     10.000000
# 1200882191875465216     8.239745
# 1150774078233387008     7.745342
# 1186989582182694922     6.194940
# 1189327302733238272     5.852217
# 1181979945599455232     5.822957
# 1141149986505330693     5.755224
# 1186830433985748993     5.545109
# 1172309499048165376     4.933798
# 1152313660787908610     4.812950
# Name: ratio, dtype: float64

# %%
#Create a column called "interactions" that contains the sum of each tweet's replies, retweets, quotes, and likes
replies = tweet["replies"].sum()
retweets = tweet["retweets"].sum()
quotes = tweet["quotes"].sum()
likes = tweet["likes"].sum()
tweet["interactions"] = replies + retweets + quotes + likes

# %%
#Find the top 8 tweets by number of "interactions"
tweet["interactions"].sort_values(ascending=False).head(8)
# Out:
# id
# 361388562              269449803
# 1249706406141292544    269449803
# 1249842026985615360    269449803
# 1249820910434967553    269449803
# 1249803348712263680    269449803
# 1249778033818558465    269449803
# 1249770830373978112    269449803
# 1249760560134213636    269449803
# Name: interactions, dtype: int64
